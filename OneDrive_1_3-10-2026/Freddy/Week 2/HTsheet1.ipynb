# %%
A,B,C = 192,-140,12

def gcd(a,b):
    r=a%b
    while r!=0:
        a=b
        b=r
        r=a%b
    return b

GCD = gcd(A,B)

if C%GCD!=0:
    print("There are no solutions")
else:
    D=A/GCD
    E=B/GCD

# %% [markdown]
# I'm not sure what the extended Euclidean Algorithm is and I can't work it out from the lecture slides or google, it just makes no sense to me. I have attempted the start of finding the answer to the problem, but cannot figure out where to go from where I am (as I imagine I need the algorithm). I have thought about part (b) but cannot really tackle it without part (a). I apologise for the lack of work provided, but I honestly have no idea what to do.
