# %% [markdown]
# <span style="color: SeaGreen; font-size: 32px;">Q1</span>
#
# <span style="color: SeaGreen; font-size: 24px;">
#
# </span>

# %% [markdown]
# <span style="color: SeaGreen; font-size: 32px;">Q2</span>
#
# <span style="color: SeaGreen; font-size: 24px;">
#
# All correct, though the derivative for 4 (c) is $1 - \frac{1}{x^2}$, so the overall reasoning is slightly off.
#
# Although $|g'(x)| < 1$ for all $x$, the Lipschitz constant/ the supremum of all derivates is $1 \not< 1$, hence not a contraction.
#
# </span>

# %% [markdown]
# <span style="color: SeaGreen; font-size: 32px;">Q2</span>
#
# <span style="color: SeaGreen; font-size: 24px;">
#
# Good stuff
#
# </span>
